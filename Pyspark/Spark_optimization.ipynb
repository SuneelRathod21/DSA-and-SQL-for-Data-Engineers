# %%
# '''1. Data Reading Optimization 
#  Bad Practice''' 
from spark.sql import SParkSession

spark = SParkSession.buid('app').getOrCreate()

df = spark.read.csv("s3:/mizedsche/sales/orders/") 

# Optimized 
# Optima = ... 
df = spark.read.schema(schema).parquet("s3://sales/orders/")
